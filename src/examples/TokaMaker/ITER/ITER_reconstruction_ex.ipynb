# %% [markdown]
# TokaMaker Example: Simple equilibrium reconstruction in ITER {#doc_tMaker_ITER_ex4}
# ==========
# In this example we show how to perform an equilibrium reconstruction in ITER from a simple with L-mode case. This example demonstrates the new reconstruction method, which leverages a multi-step approach where:
#  1) An EFIT-like quasi-linear reconstruction is performed by fitting to linearly-related DoF and constraints during the standard nonlinear solve
#  2) The reconstruction is refined using a fully general nonlinear approach that utilizes [scipy.optimize.least_squares](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.least_squares.html) and thus supports many other optimization methods
#
# This example utilizes the mesh built in \ref doc_tMaker_ITER_ex1.
#
# **Note:** Running this example requires the [h5py](https://www.h5py.org/) python package, which is installable using `pip` or other standard methods.
#
# **Warning:** The reconstruction functionality in TokaMaker is still a work in progress, as the PSI-Tri capabilities are activated and tested. Please use with care.

# %%
import os
import sys
import json
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import least_squares
plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['font.weight']='bold'
plt.rcParams['axes.labelweight']='bold'
plt.rcParams['lines.linewidth']=2
plt.rcParams['lines.markeredgewidth']=2
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ## Load TokaMaker library
#
# To load the TokaMaker python module we need to tell python where to the module is located. This can be done either through the `PYTHONPATH` environment variable or using within a script using `sys.path.append()` as below, where we look for the environement variable `OFT_ROOTPATH` to provide the path to where the OpenFUSIONToolkit is installed (`/Applications/OFT` on macOS).
#
# For meshing we will use the \ref OpenFUSIONToolkit.TokaMaker.gs_Domain "gs_Domain" class to build a 2D triangular grid suitable for Grad-Shafranov equilibria. This class uses the [triangle code](https://www.cs.cmu.edu/~quake/triangle.html) through a [python wrapper](https://pypi.org/project/triangle/).

# %%
tokamaker_python_path = os.getenv('OFT_ROOTPATH')
if tokamaker_python_path is not None:
    sys.path.append(os.path.join(tokamaker_python_path,'python'))
from OpenFUSIONToolkit import OFT_env
from OpenFUSIONToolkit.util import mu0
from OpenFUSIONToolkit.TokaMaker import TokaMaker
from OpenFUSIONToolkit.TokaMaker.meshing import load_gs_mesh
from OpenFUSIONToolkit.TokaMaker.reconstruction import reconstruction
from OpenFUSIONToolkit.TokaMaker.util import create_power_flux_fun

# %% [markdown]
# ## Initialize TokaMaker object
# We now create a \ref OpenFUSIONToolkit.OFT_env "OFT_env" instance for execution using two threads and a \ref OpenFUSIONToolkit.TokaMaker.TokaMaker "TokaMaker" instance to use for equilibrium calculations. Note at present only a single `TokaMaker` instance can be used per python kernel, so this command should only be called **once** in a given Jupyter notebook or python script. In the future this restriction may be relaxed.

# %%
myOFT = OFT_env(nthreads=2)
mygs = TokaMaker(myOFT)
# Out:
# #----------------------------------------------
# Open FUSION Toolkit Initialized
# Development branch:    tMaker_recon_picard
# Revision id:           b425d775
# Parallelization Info:
#   # of MPI tasks      =    1
#   # of NUMA nodes     =    1
#   # of OpenMP threads =    2
# Integer Precisions    =    4   8
# Float Precisions      =    4   8  16
# Complex Precisions    =    4   8
# LA backend            = native
# #----------------------------------------------

# %% [markdown]
# ### Load mesh into TokaMaker
# Now we load the mesh generated in \ref doc_tMaker_ITER_ex1 using \ref OpenFUSIONToolkit.TokaMaker.load_gs_mesh "load_gs_mesh()" and \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.setup_mesh "setup_mesh". Then we use \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.setup_regions "setup_regions()", passing the conductor and coil dictionaries for the mesh, to define the different region types. Finally, we call \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.setup "setup()" to setup the required solver objects. During this call we can specify the desired element order (min=2, max=4) and the toroidal field through F0 = B0*R0, where B0 is the toroidal field at a reference location R0.

# %%
mesh_pts,mesh_lc,mesh_reg,coil_dict,cond_dict = load_gs_mesh('ITER_mesh.h5')
mygs.setup_mesh(mesh_pts, mesh_lc, mesh_reg)
mygs.setup_regions(cond_dict=cond_dict,coil_dict=coil_dict)
mygs.setup(order = 2, F0 = -5.3*6.2)
# Out:
# **** Loading OFT surface mesh
#
# **** Generating surface grid level  1
#   Generating boundary domain linkage
#   Mesh statistics:
#     Area         =  2.859E+02
#     # of points  =    4757
#     # of edges   =   14156
#     # of cells   =    9400
#     # of boundary points =     112
#     # of boundary edges  =     112
#     # of boundary cells  =     112
#   Resolution statistics:
#     hmin =  9.924E-03
#     hrms =  2.826E-01
#     hmax =  8.466E-01
#   Surface grounded at vertex     870
#
#
# **** Creating Lagrange FE space
#   Order  =    2
#   Minlev =   -1
#
#  Computing flux BC matrix
#  Inverting real matrix
#    Time =    8.5899999999999995E-004

# %% [markdown]
# ### Define a vertical stability coil
# Like many elongated equilibria, the equilibrium we seek to compute below is vertically unstable. In this case we use the actual ITER Vertical Stability Coil (VSC) in order to help with convergence using the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.set_coil_vsc "set_coil_vsc()" method.
#
# **Note:** While ITER has a "real" VSC, this is not required and this functionality can instead be used to define a "virtual" VSC by pairing coils in a way that are not necessarily paired experimentally.

# %%
mygs.set_coil_vsc({'VS': 1.0})

# %% [markdown]
# ### Define hard limits on coil currents
# Hard limits on coil currents can be set using \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.set_coil_bounds "set_coil_bounds()". In this case we just the simple and approximate bi-directional limit of 50 MA in each coil.
#
# Bounds are specified using a dictionary of 2 element lists, containing the minimum and maximum bound, where the dictionary key corresponds to the coil names, which are available in \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.coil_sets "mygs.coil_sets"

# %%
coil_bounds = {key: [-50.E6, 50.E6] for key in mygs.coil_sets}
mygs.set_coil_bounds(coil_bounds)

# %% [markdown]
# ## Compute Equilibrium for Reconstruction
#
# ### Define global quantities and targets
# For the inverse case we define a target for the plasma current and the peak plasma pressure, which occurs on the magnetic axis.
#
# **Note:** These constraints can be considered "hard" constraints, where they will be matched to good tolerance as long as the calculation converges.

# %%
Ip_target=15.6E6
Ip_ratio_target=3.0
mygs.set_targets(Ip=Ip_target, Ip_ratio=Ip_ratio_target)

# %% [markdown]
# ### Define shape targets
# In order to constrain the shape of the plasma we can utilize two types of constraints:
#  1. `isoflux` points, which are points we want to lie on the same flux surface (eg. the LCFS)
#  2. `saddle` points, where we want the poloidal magnetic field to vanish (eg. X-points). While one can also use this constraint to enforce a magnetic axis location, instead \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.set_targets "set_targets()" should be used with arguments `R0` and `V0`.
#
# **Note:** These constraints can be considered "soft" constraints, where the calculation attempts to minimize error in satisfying these constraints subject to other constraints and regularization.
#
# Here we define a handful of isoflux points that we want to lie on the LCFS of the target equilibrium. Additionally, we define a single X-point and set it as a saddle constraint as well as adding it to the list of isoflux points.

# %%
isoflux_pts = np.array([
    [ 8.20,  0.41],
    [ 8.06,  1.46],
    [ 7.51,  2.62],
    [ 6.14,  3.78],
    [ 4.51,  3.02],
    [ 4.26,  1.33],
    [ 4.28,  0.08],
    [ 4.49, -1.34],
    [ 7.28, -1.89],
    [ 8.00, -0.68]
])
x_point = np.array([[5.125, -3.4],])
mygs.set_isoflux_constraints(np.vstack((isoflux_pts,x_point)))
mygs.set_saddle_constraints(x_point)

# %% [markdown]
# ### Define coil regularization matrix
# In general, for a given coil set a given plasma shape cannot be exactly reproduced, which generally yields large amplitude coil currents if no constraint on the coil currents is applied. As a result, it is useful to include regularization terms for the coils to balance minimization of the shape error with the amplitude of current in the coils. In TokaMaker these regularization terms have the general form, where each term corresponds to a set of coil coefficients, target value, and weight. The \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.coil_reg_term "coil_reg_term()" method is provided to aid in defining these terms.
#
# In this case, one regularization term is added for each coil with a single unit coefficient for that coil and target of zero with modest weights. This regularization acts to penalize the amplitude of current in each coil, acting to balance coil current with error in the shape targets. Note that the weight on the VSC virtual coil (`#VSC`) defined above is set high to prevent interaction with the real `VS` coil set (see below for further information).

# %%
# Set regularization weights
regularization_terms = []
for name, coil in mygs.coil_sets.items():
    # Set zero target current and different small weights to help conditioning of fit
    if name.startswith('CS'):
        if name.startswith('CS1'):
            regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=0.0,weight=2.E-2))
        else:
            regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=0.0,weight=1.E-2))
    elif name.startswith('PF'):
        regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=0.0,weight=1.E-2))
    elif name.startswith('VS'):
        regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=0.0,weight=1.E2))
# Disable VSC virtual coil
regularization_terms.append(mygs.coil_reg_term({'#VSC': 1.0},target=0.0,weight=1.E2))

# Pass regularization terms to TokaMaker
mygs.set_coil_reg(reg_terms=regularization_terms)

# %% [markdown]
# ### Define flux functions
# Although TokaMaker has a "default" profile for the F\*F' and P' terms this should almost never be used and one should instead choose an appropriate flux function for their application. In this case we use an L-mode-like profile of the form $((1-\hat{\psi})^{\alpha})^{\gamma}$, using \ref OpenFUSIONToolkit.TokaMaker.util.create_power_flux_fun "create_power_flux_fun()", where $\alpha$ and $\gamma$ are set differently for F\*F' and P' to provide peaked and broad profiles respectively. Within TokaMaker this profile is represented as a piecewise linear function, which can be set up using the dictionary approach shown below.

# %%
psihat = np.linspace(0.0,1.0,80)
ffp_prof = {
    'type': 'mlinterp',
    'x': psihat,
    'y_basis': [
        1.0-psihat,
        np.power(1.0-psihat,2)
    ],
    'weights': [2.0,]
}
ffp_prof['y'] = ffp_prof['y_basis'][0] + ffp_prof['y_basis'][1]*ffp_prof['weights'][0]

pp_prof = {
    'type': 'mlinterp',
    'x': psihat,
    'y_basis': [
        np.power(1.0-psihat,1/3),
        np.power(1.0/np.cosh(40.0*(0.95-psihat)),2)
    ],
    'weights': [2.0],
}
pp_prof['y'] = pp_prof['y_basis'][0] + pp_prof['y_basis'][1]*pp_prof['weights'][0]

fig, ax = plt.subplots(2,1,sharex=True)
# Plot F*F'
ax[0].plot(ffp_prof['x'],ffp_prof['y'])
ax[0].set_ylabel("FF'")
# Plot P'
ax[1].plot(pp_prof['x'],pp_prof['y'])
ax[1].set_ylabel("P'")
_ = ax[-1].set_xlabel(r"$\hat{\psi}$")

mygs.set_profiles(ffp_prof=ffp_prof,pp_prof=pp_prof)

# %% [markdown]
# ### Compute equilibrium
# We can now compute a free-boundary equilibrium using these constraints. Note that before running a calculation for the first time we must initialize the flux function $\psi$, which can be done using \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.init_psi "init_psi()". This subroutine initializes the flux using the specified Ip_target from above, which is evenly distributed over the entire plasma region or only with a boundary defined using a center point (R,Z), minor radius (a), and elongation and triangularity. Coil currents are also initialized at this point using the constraints above and this uniform plasma current initialization.
#
# \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.solve "solve()" is then called to compute a self-consitent Grad-Shafranov equilibrium. If the result variable (`err_flag`) is zero then the solution has converged to the desired tolerance ($10^{-6}$ by default).

# %%
R0 = 6.3
Z0 = 0.5
a = 2.0
kappa = 1.4
delta = 0.0
mygs.init_psi(R0, Z0, a, kappa, delta)
EQ_target = mygs.solve()
target_stats = mygs.get_stats()
# Out:
# Starting non-linear GS solver
#      1  8.2775E+00  4.5346E-02  2.5053E-01  6.3670E+00  5.2517E-01  5.1278E+00
#      2  9.2818E+00  4.3811E-02  1.2032E-01  6.3542E+00  5.2850E-01 -1.0532E-01
#      3  9.8332E+00  4.4199E-02  4.8727E-02  6.3488E+00  5.3104E-01 -1.6270E+00
#      4  1.0088E+01  4.4362E-02  2.2631E-02  6.3463E+00  5.3295E-01 -2.2306E+00
#      5  1.0205E+01  4.4440E-02  1.1259E-02  6.3452E+00  5.3436E-01 -2.4918E+00
#      6  1.0260E+01  4.4473E-02  5.5355E-03  6.3448E+00  5.3537E-01 -2.6162E+00
#      7  1.0285E+01  4.4488E-02  2.8275E-03  6.3445E+00  5.3609E-01 -2.6794E+00
#      8  1.0297E+01  4.4495E-02  1.3839E-03  6.3444E+00  5.3660E-01 -2.7080E+00
#      9  1.0302E+01  4.4499E-02  6.8286E-04  6.3444E+00  5.3695E-01 -2.7236E+00
#     10  1.0305E+01  4.4501E-02  3.4760E-04  6.3444E+00  5.3719E-01 -2.7305E+00
#     11  1.0306E+01  4.4502E-02  1.9076E-04  6.3443E+00  5.3736E-01 -2.7339E+00
#     12  1.0307E+01  4.4502E-02  1.0669E-04  6.3443E+00  5.3748E-01 -2.7358E+00
#     13  1.0307E+01  4.4502E-02  6.4925E-05  6.3443E+00  5.3756E-01 -2.7368E+00
#     14  1.0307E+01  4.4502E-02  4.1959E-05  6.3443E+00  5.3762E-01 -2.7373E+00
#     15  1.0307E+01  4.4502E-02  2.8095E-05  6.3443E+00  5.3765E-01 -2.7376E+00
#     16  1.0307E+01  4.4502E-02  1.9155E-05  6.3443E+00  5.3768E-01 -2.7378E+00
#     17  1.0307E+01  4.4502E-02  1.3169E-05  6.3443E+00  5.3770E-01 -2.7379E+00
#     18  1.0307E+01  4.4502E-02  9.0850E-06  6.3443E+00  5.3771E-01 -2.7380E+00
#     19  1.0307E+01  4.4502E-02  6.2759E-06  6.3443E+00  5.3772E-01 -2.7380E+00
#     20  1.0307E+01  4.4502E-02  4.3368E-06  6.3443E+00  5.3773E-01 -2.7381E+00
#     21  1.0307E+01  4.4502E-02  2.9967E-06  6.3443E+00  5.3773E-01 -2.7381E+00
#     22  1.0307E+01  4.4502E-02  2.0704E-06  6.3443E+00  5.3773E-01 -2.7381E+00
#     23  1.0307E+01  4.4502E-02  1.4303E-06  6.3443E+00  5.3774E-01 -2.7381E+00
#     24  1.0307E+01  4.4502E-02  9.8787E-07  6.3443E+00  5.3774E-01 -2.7381E+00
#  Timing:  0.41402900000684895
#    Source:    0.10254599999461789
#    Solve:     0.26999399998749141
#    Boundary:   4.5769999996991828E-003
#    Other:      3.6912000025040470E-002

# %% [markdown]
# ### Plot equilibrium
# Flux surfaces of the computed equilibrium can be plotted using the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.plot_psi "plot_psi()" method. The additional plotting methods \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.plot_machine "plot_machine()" and \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.plot_constraints "plot_constraints()" are also used to show context and other information. Each method has a large number of optional arguments for formatting and other options.

# %%
fig, ax = plt.subplots(1,1)
mygs.plot_machine(fig,ax,coil_colormap='seismic',coil_symmap=True,coil_scale=1.E-6,coil_clabel=r'$I_C$ [MA]')
mygs.plot_psi(fig,ax,xpoint_color=None,vacuum_nlevels=4)
mygs.plot_constraints(fig,ax,isoflux_color='tab:red',isoflux_marker='o')

# %% [markdown]
# ### Print equilibrium information and coil currents
# Basic parameters can be displayed using the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.print_info "print_info()" method. For access to these quantities as variables instead the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.get_stats "get_stats()" can be used.
#
# The final coil currents can also be retrieved using the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.get_coil_currents "get_coil_currents()" method, which are all within the approximate coil limits imposed above.

# %%
mygs.print_info()

print()
print("Coil Currents [MA]:")
ref_currents, _ = mygs.get_coil_currents()
for key, current in ref_currents.items():
    print('  {0:10} {1:10.2F}'.format(key+":",current/1.E6))
# Out:
# Equilibrium Statistics:
#   Topology                =   Diverted
#   Toroidal Current [A]    =    1.5600E+07
#   Current Centroid [m]    =    6.162  0.515
#   Magnetic Axis [m]       =    6.344  0.538
#   Elongation              =    1.863 (U:  1.721, L:  2.006)
#   Triangularity           =    0.453 (U:  0.356, L:  0.551)
#   Plasma Volume [m^3]     =   810.854
#   q_0, q_95               =   -0.594 -2.812
#   Plasma Pressure [Pa]    =   Axis:  4.2936E+05, Peak:  4.2936E+05
#   Stored Energy [J]       =    1.9992E+08
#   <Beta_pol> [%]          =   34.8745
#   <Beta_tor> [%]          =    1.4813
#   <Beta_n>   [%]          =    0.9915
#   Diamagnetic flux [Wb]   =   -1.6343E+00
#   Toroidal flux [Wb]      =   -1.2036E+02
#   l_i                     =    1.0651
#
# Coil Currents [MA]:
#   CS3U:           14.01
#   CS2U:            9.33
#   CS1U:           -9.12
#   CS1L:           -7.42
#   CS2L:            8.57
#   CS3L:           16.83
#   PF1:            10.78
#   PF2:            -1.49
#   PF3:            -6.16
#   PF4:            -3.97
#   PF5:            -8.45
#   PF6:            24.57
#   VS:             -0.00

# %% [markdown]
# ## Perform Reconstruction
# We now create the \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction "reconstruction" object to reconstruct the equilibrium above from only diagnostic information.

# %%
myrecon = reconstruction(mygs)

# %% [markdown]
# ### Define diagnostic set
# For this example we define a simple set of flux loops and Mirnov sensors that lie on the inner vaccum vessel. The signal in these sensors will be used to constrain the reconstruction along with coil currents and global plasma quantities (eg. $I_p$).

# %%
nProbes = 20
# Load VV geometry
with open('ITER_geom.json','r') as fid:
    ITER_geom = json.load(fid)
    probe_contour = np.asarray(ITER_geom['inner_vv'][0])
# Rediscretize evenly in arc length
dl_contour = np.r_[0.0, np.cumsum(np.linalg.norm(np.diff(probe_contour,axis=0),axis=1))]
probe_contour_new = np.zeros((nProbes,2))
probe_contour_new[:,0] = np.interp(np.linspace(0.0,dl_contour[-1],nProbes,endpoint=False),dl_contour,probe_contour[:,0])
probe_contour_new[:,1] = np.interp(np.linspace(0.0,dl_contour[-1],nProbes,endpoint=False),dl_contour,probe_contour[:,1])
# Place probe locations evenly on contour
Floop_locs = []
for i, pt in enumerate(probe_contour_new):
    Floop_locs.append(pt)
Floop_locs = np.asarray(Floop_locs)
# Define two Thomson sampling chords (vertical and horizontal)
Thom_locs = []
for i, a in enumerate(np.linspace(0.0,1.0,40)):
    Thom_locs.append(np.r_[mygs.o_point[0]+a*(8.25-mygs.o_point[0]), mygs.o_point[1]])
for i, a in enumerate(np.linspace(0.0,1.0,40)):
    Thom_locs.append(np.r_[mygs.o_point[0], mygs.o_point[1]+a*(3.75-mygs.o_point[1])])
Thom_locs = np.asarray(Thom_locs)

# %% [markdown]
# We also define a helper function to add Gaussian noise to signals based on a relative and absolute error.

# %%
random.seed(1) # Ensure reproducible sampling, comment for truly random
def add_noise(signal,rel_err,abs_err=0.0):
    noise_rel = rel_err*random.gauss(0.0,1.0)
    noise_abs = abs_err*random.gauss(0.0,0.5)
    return signal*(1.0+noise_rel) + noise_abs

# %% [markdown]
# #### Set plasma current constraint
# First we define a constraint on the plasma current with 2% relative and 100 kA absolute Gaussian noise added to the signal and corresponding error. This constraint is equivalent to the measurement of a synthetic Rigowskii coil and can be set using \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.set_Ip "set_Ip()".

# %%
Ip_rerr = 0.02
Ip_aerr = 1.E5
Ip_noised = add_noise(target_stats['Ip'],Ip_rerr)
myrecon.set_Ip(Ip_noised, err=Ip_rerr*abs(Ip_noised)+Ip_aerr)

# %% [markdown]
# #### Set diamagnetic flux constraint
# Next we define a constraint on the diamagnetic flux with 5% relative and 100 mWb absolute Gaussian noise added to the signal and corresponding error. This constraint is equivalent to the measurement of a synthetic Diamagnetic flux loop and can be set using \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.set_DFlux "set_DFlux()".

# %%
Dflux_rerr = 0.05
Dflux_aerr = 1.E-1
Dflux_noised = add_noise(target_stats['dflux'],Dflux_rerr)
myrecon.set_DFlux(Dflux_noised, err=Dflux_rerr*abs(Dflux_noised)+Dflux_aerr)

# %% [markdown]
# #### Set plasma pressure constraints
# Next we define constraints on the plasma pressure corresponding to the Thomson chords constructed above. Each point has a 10% relative and 3 kPa absolute Gaussian noise added to the signal and corresponding error. This constraint is equivalent to the measurement of synthetic Thomson points and can be set using \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.add_pressure "add_pressure()".

# %%
thomson_rerr = 0.1
thomson_aerr = 3.E4
thomson_vals = []
field_eval = EQ_target.get_field_eval('P')
for i in range(Thom_locs.shape[0]):
    P_val = field_eval.eval(Thom_locs[i,:])[0]
    P_val = max(thomson_aerr*0.1,add_noise(P_val,thomson_rerr))
    thomson_vals.append(P_val)
    myrecon.add_pressure(Thom_locs[i,:], P_val, err=thomson_rerr*abs(P_val)+thomson_aerr)

# %% [markdown]
# #### Set flux loop constraints
# Next we sample the poloidal flux at each of the locations defined above with 2% relative and 1 Wb absolute Gaussian noise added to each signal. Flux loop constraints are defined using \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.add_flux_loop "add_flux_loop()".
#
# **Note:** Poloidal flux and $\psi$ differ by a factor of $2 \pi$ that must be accounted for when computing synthetic flux loop signals from an existing equilibrium.

# %%
floop_rerr = 0.02
floop_aerr = 1.0
floop_vals = []
field_eval = EQ_target.get_field_eval('PSI')
for i in range(Floop_locs.shape[0]):
    flux_val = field_eval.eval(Floop_locs[i,:])[0]*2.0*np.pi
    flux_val = add_noise(flux_val,floop_rerr)
    floop_vals.append(flux_val)
    myrecon.add_flux_loop(Floop_locs[i,:], flux_val, err=floop_rerr*abs(flux_val)+floop_aerr)
floop_vals = np.array(floop_vals)
floop_wts = np.array([1.0/(floop_rerr*abs(flux_val)+floop_aerr) for flux_val in floop_vals])

# %% [markdown]
# #### Set Mirnov constraints
# Next we sample the radial and vertical magnetic field at each of the locations defined above with 2% relative and 50 mT absolute Gaussian noise added to each signal. Local B-field constraints are defined using \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.add_Mirnov "add_Mirnov()".

# %%
mag_rerr = 0.02
mag_aerr = 5.E-2
Mirnov_locs = []
Mirnov_norms = []
mirnov_vals = []
mirnov_wts = []
field_eval = EQ_target.get_field_eval('B')
for i in range(Floop_locs.shape[0]-1):
    pt = (Floop_locs[i,:]+Floop_locs[i+1,:])/2.0
    B_tmp = field_eval.eval(pt)
    for j in range(4):
        B_noised = [add_noise(val,mag_rerr) for val in B_tmp]
        mag_local = np.linalg.norm(np.r_[B_noised[0], B_noised[2]])
        #
        B_err = mag_rerr*abs(B_noised[0])+mag_aerr
        myrecon.add_Mirnov(pt, np.r_[1.0,0.0,0.0], B_noised[0], err=B_err)
        mirnov_vals.append(B_noised[0])
        mirnov_wts.append(1.0/B_err)
        Mirnov_locs.append(pt)
        Mirnov_norms.append(np.r_[1.0,0.0])
        #
        B_err = mag_rerr*abs(B_noised[2])+mag_aerr
        myrecon.add_Mirnov(pt, np.r_[0.0,0.0,1.0], B_noised[2], err=B_err)
        mirnov_vals.append(B_noised[2])
        mirnov_wts.append(1.0/B_err)
        Mirnov_locs.append(pt)
        Mirnov_norms.append(np.r_[0.0,1.0])
mirnov_vals = np.array(mirnov_vals)
mirnov_wts = np.array(mirnov_wts)
Mirnov_norms = np.array(Mirnov_norms)
Mirnov_locs = np.array(Mirnov_locs)

# %% [markdown]
# #### Set Coil constraints
# Finally we add 1% relative and 100 kA-turn absolute noise to each coil current and define reconstruction constraints using \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.set_coil_currents "set_coil_currents()".

# %%
coil_rerr = 0.01
coil_aerr = 1.E5
coil_targets = {name: add_noise(current,coil_rerr) for name, current in ref_currents.items()}
coil_err = {name: coil_rerr*abs(current)+coil_aerr for name, current in ref_currents.items()}
coil_err['VS'] = 1.E3 # Set lower error on VS coil
myrecon.set_coil_currents(coil_targets,coil_err)

# %% [markdown]
# #### Plot constraint locations

# %%
fig, ax = plt.subplots(1,1)
mygs.plot_machine(fig,ax,coil_colormap=None)
mygs.plot_psi(fig,ax,plasma_nlevels=5,vacuum_nlevels=5)
myrecon.plot_constraints(fig, ax)

# %% [markdown]
# ### Compute starting equilibrium

# %%
# Reset constraints from above
mygs.set_isoflux_constraints(None)
mygs.set_saddle_constraints(None)

# Set new constraints based on flux loops and Mirnovs
mygs.set_flux_constraints(Floop_locs,floop_vals,weights=floop_wts)
mygs.set_mirnov_constraints(Mirnov_locs,Mirnov_norms,mirnov_vals,weights=mirnov_wts/8.0) # Reduce weight on Mirnovs by redundancy factor

# Set coil regularization to weakly track measured coil currents
regularization_terms = []
for name, current in coil_targets.items():
    regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=current,weight=1.E-1/(coil_err[name]*mu0)))
regularization_terms.append(mygs.coil_reg_term({'#VSC': 1.0},target=0.0,weight=1.E2))
mygs.set_coil_reg(reg_terms=regularization_terms)

# Modify flux functions to "unknown" state
ffp_prof['weights'] = [0.1]
pp_prof['weights'] = [0.1]
mygs.set_profiles(ffp_prof=ffp_prof,pp_prof=pp_prof)

# Initial equilibrium with very rough guess
R0 = 6.0
Z0 = 0.0
a = 1.5
kappa = 1.0
delta = 0.0
mygs.set_targets(Ip=Ip_noised)
err_flag = mygs.init_psi(R0, Z0, a, kappa, delta)

# Set soft targets for Ip and Dflux (need to call `.update_settings()` after, see below)
mygs.set_targets(Ip=Ip_noised,Dflux=Dflux_noised)
mygs.settings.ffp_target_weight=1.0/((Ip_rerr*abs(Ip_noised)+Ip_aerr)*mu0)
mygs.settings.pp_target_weight=1.E-1/(Dflux_rerr*abs(Dflux_noised)+Dflux_aerr)

# Update settings for nonlinear solve
mygs.settings.maxits=400
mygs.settings.urf=0.0
mygs.update_settings()

# Compute initial equilibrium
EQ_guess = mygs.solve()
# Out:
# Starting non-linear GS solver
#      1  8.5568E+00  1.7700E-01  5.1892E-02  6.4059E+00  9.7376E-02  6.2213E+02
#      2  1.9530E+01  6.9838E-02  1.2827E-02  6.3734E+00  1.4878E-01  6.7783E+02
#      3  1.7959E+01  8.5337E-02  1.0039E-02  6.3757E+00  1.9599E-01  6.6627E+02
#      4  1.9416E+01  7.1018E-02  8.2304E-03  6.3668E+00  2.3504E-01  6.1913E+02
#      5  1.8407E+01  7.8374E-02  7.6746E-03  6.3689E+00  2.7066E-01  5.7732E+02
#      6  1.9023E+01  7.1181E-02  6.6159E-03  6.3645E+00  3.0166E-01  5.3130E+02
#      7  1.8464E+01  7.4648E-02  6.0222E-03  6.3651E+00  3.3046E-01  4.9440E+02
#      8  1.8726E+01  7.0910E-02  5.3076E-03  6.3623E+00  3.5542E-01  4.5814E+02
#      9  1.8392E+01  7.2647E-02  4.7453E-03  6.3623E+00  3.7801E-01  4.2858E+02
#     10  1.8485E+01  7.0699E-02  4.1659E-03  6.3605E+00  3.9797E-01  4.0039E+02
#     11  1.8278E+01  7.1572E-02  3.7033E-03  6.3603E+00  4.1574E-01  3.7674E+02
#     12  1.8293E+01  7.0556E-02  3.2279E-03  6.3592E+00  4.3150E-01  3.5509E+02
#     13  1.8164E+01  7.0935E-02  2.8485E-03  6.3589E+00  4.4548E-01  3.3670E+02
#     14  1.8144E+01  7.0430E-02  2.5073E-03  6.3582E+00  4.5770E-01  3.2012E+02
#     15  1.8058E+01  7.0604E-02  2.1974E-03  6.3579E+00  4.6846E-01  3.0588E+02
#     16  1.8025E+01  7.0370E-02  1.9256E-03  6.3575E+00  4.7791E-01  2.9316E+02
#     17  1.7965E+01  7.0442E-02  1.7021E-03  6.3572E+00  4.8625E-01  2.8222E+02
#     18  1.7932E+01  7.0325E-02  1.4870E-03  6.3568E+00  4.9367E-01  2.7254E+02
#     19  1.7890E+01  7.0345E-02  1.3002E-03  6.3566E+00  5.0017E-01  2.6412E+02
#     20  1.7861E+01  7.0292E-02  1.1309E-03  6.3563E+00  5.0588E-01  2.5675E+02
#     21  1.7831E+01  7.0291E-02  9.8845E-04  6.3561E+00  5.1087E-01  2.5038E+02
#     22  1.7806E+01  7.0275E-02  8.6361E-04  6.3560E+00  5.1523E-01  2.4477E+02
#     23  1.7782E+01  7.0278E-02  7.4916E-04  6.3558E+00  5.1904E-01  2.3987E+02
#     24  1.7762E+01  7.0273E-02  6.5034E-04  6.3557E+00  5.2236E-01  2.3560E+02
#     25  1.7744E+01  7.0278E-02  5.6762E-04  6.3556E+00  5.2526E-01  2.3189E+02
#     26  1.7728E+01  7.0278E-02  4.9519E-04  6.3555E+00  5.2778E-01  2.2866E+02
#     27  1.7714E+01  7.0283E-02  4.3231E-04  6.3554E+00  5.2997E-01  2.2584E+02
#     28  1.7702E+01  7.0286E-02  3.7690E-04  6.3554E+00  5.3188E-01  2.2339E+02
#     29  1.7692E+01  7.0289E-02  3.2924E-04  6.3553E+00  5.3354E-01  2.2124E+02
#     30  1.7682E+01  7.0292E-02  2.8669E-04  6.3552E+00  5.3499E-01  2.1937E+02
#     31  1.7675E+01  7.0292E-02  2.4907E-04  6.3552E+00  5.3625E-01  2.1774E+02
#     32  1.7667E+01  7.0296E-02  2.1655E-04  6.3552E+00  5.3735E-01  2.1634E+02
#     33  1.7661E+01  7.0300E-02  1.8784E-04  6.3551E+00  5.3831E-01  2.1510E+02
#     34  1.7656E+01  7.0300E-02  1.6373E-04  6.3551E+00  5.3914E-01  2.1404E+02
#     35  1.7651E+01  7.0303E-02  1.4279E-04  6.3551E+00  5.3986E-01  2.1312E+02
#     36  1.7647E+01  7.0304E-02  1.2394E-04  6.3550E+00  5.4049E-01  2.1232E+02
#     37  1.7643E+01  7.0305E-02  1.0796E-04  6.3550E+00  5.4104E-01  2.1163E+02
#     38  1.7640E+01  7.0307E-02  9.3781E-05  6.3550E+00  5.4152E-01  2.1102E+02
#     39  1.7638E+01  7.0307E-02  8.1327E-05  6.3550E+00  5.4193E-01  2.1049E+02
#     40  1.7635E+01  7.0309E-02  7.1060E-05  6.3550E+00  5.4229E-01  2.1004E+02
#     41  1.7633E+01  7.0309E-02  6.1759E-05  6.3550E+00  5.4261E-01  2.0964E+02
#     42  1.7632E+01  7.0310E-02  5.3894E-05  6.3550E+00  5.4288E-01  2.0929E+02
#     43  1.7630E+01  7.0311E-02  4.6674E-05  6.3550E+00  5.4312E-01  2.0899E+02
#     44  1.7629E+01  7.0312E-02  4.0519E-05  6.3550E+00  5.4332E-01  2.0873E+02
#     45  1.7628E+01  7.0312E-02  3.5006E-05  6.3549E+00  5.4350E-01  2.0850E+02
#     46  1.7627E+01  7.0312E-02  3.0441E-05  6.3549E+00  5.4366E-01  2.0830E+02
#     47  1.7626E+01  7.0313E-02  2.6570E-05  6.3549E+00  5.4380E-01  2.0813E+02
#     48  1.7625E+01  7.0313E-02  2.2985E-05  6.3549E+00  5.4391E-01  2.0798E+02
#     49  1.7624E+01  7.0313E-02  2.0099E-05  6.3549E+00  5.4401E-01  2.0786E+02
#     50  1.7624E+01  7.0314E-02  1.7289E-05  6.3549E+00  5.4410E-01  2.0774E+02
#     51  1.7623E+01  7.0314E-02  1.5098E-05  6.3549E+00  5.4418E-01  2.0765E+02
#     52  1.7623E+01  7.0314E-02  1.3164E-05  6.3549E+00  5.4425E-01  2.0756E+02
#     53  1.7622E+01  7.0314E-02  1.1330E-05  6.3549E+00  5.4430E-01  2.0749E+02
#     54  1.7622E+01  7.0314E-02  9.8614E-06  6.3549E+00  5.4435E-01  2.0742E+02
#     55  1.7622E+01  7.0315E-02  8.5061E-06  6.3549E+00  5.4440E-01  2.0737E+02
#     56  1.7621E+01  7.0315E-02  7.3721E-06  6.3549E+00  5.4444E-01  2.0732E+02
#     57  1.7621E+01  7.0315E-02  6.3880E-06  6.3549E+00  5.4447E-01  2.0728E+02
#     58  1.7621E+01  7.0315E-02  5.5350E-06  6.3549E+00  5.4450E-01  2.0724E+02
#     59  1.7621E+01  7.0315E-02  4.7960E-06  6.3549E+00  5.4452E-01  2.0721E+02
#     60  1.7621E+01  7.0315E-02  4.1553E-06  6.3549E+00  5.4454E-01  2.0718E+02
#     61  1.7621E+01  7.0315E-02  4.0560E-06  6.3549E+00  5.4456E-01  2.0716E+02
#     62  1.7621E+01  7.0315E-02  3.1418E-06  6.3549E+00  5.4458E-01  2.0714E+02
#     63  1.7620E+01  7.0315E-02  2.7213E-06  6.3549E+00  5.4459E-01  2.0712E+02
#     64  1.7620E+01  7.0315E-02  2.3584E-06  6.3549E+00  5.4460E-01  2.0711E+02
#     65  1.7620E+01  7.0315E-02  2.0434E-06  6.3549E+00  5.4461E-01  2.0709E+02
#     66  1.7620E+01  7.0315E-02  1.7710E-06  6.3549E+00  5.4462E-01  2.0708E+02
#     67  1.7620E+01  7.0315E-02  1.5346E-06  6.3549E+00  5.4463E-01  2.0707E+02
#     68  1.7620E+01  7.0315E-02  1.3299E-06  6.3549E+00  5.4464E-01  2.0706E+02
#     69  1.7620E+01  7.0315E-02  1.1524E-06  6.3549E+00  5.4464E-01  2.0706E+02
#     70  1.7620E+01  7.0315E-02  9.9868E-07  6.3549E+00  5.4465E-01  2.0705E+02
#  Timing:   1.2663840000022901
#    Source:    0.29482799998368137
#    Solve:     0.80394900008104742
#    Boundary:   1.3181000016629696E-002
#    Other:     0.15442599992093164

# %% [markdown]
# ### Plot starting equilibrium

# %%
EQ_guess = mygs.copy_eq()
EQ_guess.print_info()

print()
print("Coil Currents [MA]:")
coil_currents, _ = EQ_guess.get_coil_currents()
for key, current in coil_currents.items():
    print('  {0:10} {1:10.2F}'.format(key+":",current/1.E6))

# Plot first case surfaces
fig, ax = plt.subplots(1,1)
mygs.plot_machine(fig,ax,equilibrium=EQ_guess,coil_colormap='seismic',coil_scale=1.E-6,coil_clabel=r'$I_C$ [MA]',coil_symmap=True)
mygs.plot_psi(fig,ax,equilibrium=EQ_guess,plasma_nlevels=5,vacuum_nlevels=5)
mygs.plot_psi(fig,ax,equilibrium=EQ_target,plasma_levels=[1.0,],plasma_color='red',vacuum_nlevels=0,plasma_linestyles='dashed')
# Out:
# Equilibrium Statistics:
#   Topology                =   Diverted
#   Toroidal Current [A]    =    1.5927E+07
#   Current Centroid [m]    =    6.146  0.529
#   Magnetic Axis [m]       =    6.355  0.545
#   Elongation              =    1.888 (U:  1.750, L:  2.026)
#   Triangularity           =    0.461 (U:  0.370, L:  0.551)
#   Plasma Volume [m^3]     =   821.036
#   q_0, q_95               =   -0.856 -2.761
#   Plasma Pressure [Pa]    =   Axis:  5.3701E+05, Peak:  5.3701E+05
#   Stored Energy [J]       =    2.3366E+08
#   <Beta_pol> [%]          =   39.1906
#   <Beta_tor> [%]          =    1.7091
#   <Beta_n>   [%]          =    1.1139
#   Diamagnetic flux [Wb]   =   -1.5602E+00
#   Toroidal flux [Wb]      =   -1.2202E+02
#   l_i                     =    0.9281
#
# Coil Currents [MA]:
#   CS3U:           14.55
#   CS2U:            9.79
#   CS1U:           -9.62
#   CS1L:           -7.63
#   CS2L:            8.06
#   CS3L:           16.74
#   PF1:            10.35
#   PF2:            -1.75
#   PF3:            -6.01
#   PF4:            -3.94
#   PF5:            -8.79
#   PF6:            25.08
#   VS:              0.00

# %% [markdown]
# ### Plot starting error

# %%
myrecon.setup_constraints()

fig, ax = plt.subplots(2,2,constrained_layout=True)
fig2, (coil_ax, chi_ax) = plt.subplots(2,1,constrained_layout=True)
myrecon.plot_error(ax.flatten(),coil_ax=coil_ax,chi_ax=chi_ax)

# %% [markdown]
# ## Perform fit using Python optimization routines
# We now refine the reconstruction by applying a general nonlinear optimization approach over the inner diagnostic-constrained nonlinear solve. The \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction "TokaMaker reconstruction object" has several helper functions to support this for optimization approaches that use callable error and Jacobian functions as shown below for the [scipy.optimize.least_squares](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.least_squares.html) method, which uses both callable functions with a Levenberg–Marquardt algorithm.
#
# **Note:** The \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.opt_error "opt_error()" and \ref OpenFUSIONToolkit.TokaMaker.reconstruction.reconstruction.opt_error_jacobian "opt_error_jacobian()" functions both have the same call signature, which includes the DoF vector, reconstruction object, and a logical flag that should be set `False` in arguments passed to the optimizer.

# %%
mygs.settings.pm=False
mygs.update_settings()

# Configure reconstruction settings
myrecon.settings.fitF = True
myrecon.settings.fitP = True
myrecon.settings.fit_Pscale = True
myrecon.settings.fit_FFPscale = False
myrecon.settings.fitR0 = False
myrecon.settings.fitZ0 = False
myrecon.settings.fixedCentering = False
myrecon.settings.dx = 1.E-2

# Set targets for inner solve
mygs.set_targets(Ip=Ip_noised)
mygs.settings.ffp_target_weight=1.0/((Ip_rerr*abs(Ip_noised)+Ip_aerr)*mu0)

x0_nl, err_in = myrecon.setup_get_opt()

opt_result = least_squares(myrecon.opt_error, x0_nl, jac=myrecon.opt_error_jacobian, method='lm', ftol=1.E-3, args=(myrecon,False))

print()
print(opt_result)

mygs.settings.pm=True
mygs.update_settings()
# Out:
# chi_rms = 1.0521E+00; chi_max = 4.1317E+00
# chi_rms = 8.5389E-01; chi_max = 3.4197E+00
# chi_rms = 5.8139E-01; chi_max = 4.5249E+00
# chi_rms = 5.2645E-01; chi_max = 3.8078E+00
# chi_rms = 5.2468E-01; chi_max = 3.8389E+00
# chi_rms = 5.2465E-01; chi_max = 3.8233E+00
#
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.246e-01 -3.450e-01 ...  1.864e-01  4.209e-01]
#            x: [ 4.280e-02  1.920e+00  2.204e+00]
#         cost: 36.74649712850666
#          jac: [[ 8.190e+00 -2.660e-02  6.123e-02]
#                [ 9.480e+00 -1.645e-02  7.830e-02]
#                ...
#                [-4.179e+00  2.074e-03 -3.679e-02]
#                [-9.482e+01  1.829e-02 -5.502e-01]]
#         grad: [ 1.391e+00  1.605e-01 -1.180e-01]
#   optimality: 1.3908493461582598
#  active_mask: [0 0 0]
#         nfev: 5
#         njev: 4

# %% [markdown]
# ### Plot final reconstruction error

# %%
fig, ax = plt.subplots(2,2,constrained_layout=True)
fig2, (coil_ax, chi_ax) = plt.subplots(2,1,constrained_layout=True)
myrecon.plot_error(ax.flatten(),coil_ax=coil_ax,chi_ax=chi_ax)

# %% [markdown]
# ### Plot final reconstructed solution

# %%
mygs.print_info()

print()
print("Coil Currents [MA]:")
print("  {0:10} {1:10} {2:10} {3:10} {4:10}".format("Name","Reconstructed","Target","Ground Truth", "% Error from target"))
coil_ref, _ = EQ_target.get_coil_currents()
coil_currents, _ = mygs.get_coil_currents()
for key, current in coil_currents.items():
    if key == 'VS':
        print('  {0:10} {1:10.2F} {2:10.2F} {3:10.2F} {4:10.2F}'.format(key+":",current/1.E3,coil_targets[key]/1.E3,coil_ref[key]/1.E3,100.0*(current-coil_ref[key])/abs(coil_ref[key])))
    else:
        print('  {0:10} {1:10.2F} {2:10.2F} {3:10.2F} {4:10.2F}'.format(key+":",current/1.E6,coil_targets[key]/1.E6,coil_ref[key]/1.E6,100.0*(current-coil_ref[key])/abs(coil_ref[key])))

# Plot first case surfaces
fig, ax = plt.subplots(1,1)
mygs.plot_machine(fig,ax,coil_colormap='seismic',coil_scale=1.E-6,coil_clabel=r'$I_C$ [MA]',coil_symmap=True)
mygs.plot_psi(fig,ax,plasma_nlevels=5,vacuum_nlevels=5)
mygs.plot_psi(fig,ax,equilibrium=EQ_target,plasma_nlevels=5,plasma_color='red',vacuum_nlevels=0,plasma_linestyles='dashed')
# Out:
# Equilibrium Statistics:
#   Topology                =   Diverted
#   Toroidal Current [A]    =    1.5924E+07
#   Current Centroid [m]    =    6.161  0.533
#   Magnetic Axis [m]       =    6.347  0.556
#   Elongation              =    1.862 (U:  1.719, L:  2.006)
#   Triangularity           =    0.456 (U:  0.367, L:  0.545)
#   Plasma Volume [m^3]     =   820.243
#   q_0, q_95               =   -0.587 -2.799
#   Plasma Pressure [Pa]    =   Axis:  4.2561E+05, Peak:  4.2561E+05
#   Stored Energy [J]       =    2.0355E+08
#   <Beta_pol> [%]          =   34.0142
#   <Beta_tor> [%]          =    1.4921
#   <Beta_n>   [%]          =    0.9838
#   Diamagnetic flux [Wb]   =   -1.7164E+00
#   Toroidal flux [Wb]      =   -1.2187E+02
#   l_i                     =    1.0588
#
# Coil Currents [MA]:
#   Name       Reconstructed Target     Ground Truth % Error from target
#   CS3U:           14.62      14.05      14.01       4.36
#   CS2U:            9.85       9.38       9.33       5.61
#   CS1U:           -9.81      -9.08      -9.12      -7.60
#   CS1L:           -7.67      -7.28      -7.42      -3.27
#   CS2L:            8.18       8.43       8.57      -4.55
#   CS3L:           16.86      16.83      16.83       0.16
#   PF1:            10.29      10.80      10.78      -4.57
#   PF2:            -1.55      -1.50      -1.49      -4.02
#   PF3:            -6.24      -6.21      -6.16      -1.30
#   PF4:            -3.97      -4.00      -3.97      -0.04
#   PF5:            -8.61      -8.55      -8.45      -1.88
#   PF6:            24.92      24.66      24.57       1.42
#   VS:              0.10      -0.01      -0.01    1886.98
