# %% [markdown]
# TokaMaker Meshing Example: Building a mesh for NSTX-U
# ==========
# In this example we show how to generate a mesh for the NSTX-U device using TokaMaker's built in mesh generation.
#
# **Note:** Running this example requires the [h5py](https://www.h5py.org/) python packages, which is installable using `pip` or other standard methods.

# %%
import os
import sys
import json
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['font.weight']='bold'
plt.rcParams['axes.labelweight']='bold'
plt.rcParams['lines.linewidth']=2
plt.rcParams['lines.markeredgewidth']=2
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ## Load TokaMaker library
#
# To load the TokaMaker python module we need to tell python where to the module is located. This can be done either through the `PYTHONPATH` environment variable or using within a script using `sys.path.append()` as below, where we look for the environement variable `OFT_ROOTPATH` to provide the path to where the OpenFUSIONToolkit is installed (`/Applications/OFT` on macOS).
#
# For meshing we will use the \ref OpenFUSIONToolkit.TokaMaker.gs_Domain "gs_Domain" class to build a 2D triangular grid suitable for Grad-Shafranov equilibria. This class uses the [triangle code](https://www.cs.cmu.edu/~quake/triangle.html) through a simple internal python wrapper within OFT.

# %%
tokamaker_python_path = os.getenv('OFT_ROOTPATH')
if tokamaker_python_path is not None:
    sys.path.append(os.path.join(tokamaker_python_path,'python'))
from OpenFUSIONToolkit.TokaMaker.meshing import gs_Domain, save_gs_mesh

# %% [markdown]
# ## Load geometry information
# The geometry information (eg. bounding curves for vacuum vessels) are now loaded from a JSON file. For simple geometries, testing, or generative usage this can be created directly in the code. However, it is often helpful to separate this information into a fixed datafile as here. This JSON file contains the following:
#  - `limiter`: A contour of R,Z points defining the limiter (PFC) surface
#  - `vv`: Multiple contours of R,Z points defining the vacuum vessel as a set of poloidal segments
#  - `coils`: A dictionary of values defining the E and F coils in the poloidal cross-section

# %%
#Load geometry information
with open('NSTXU_geom.json','r') as fid:
    NSTXU_geom = json.load(fid)

# %% [markdown]
# ## Set mesh resolution for each region
# First we define some target sizes to set the resolution in out grid. These variables will be used later and represent the target edge size within a given region, where units are in meters. In this case we are using a fairly coarse resolution of 6 cm in the plasma region and 14 cm in the vacuum region.
#
# **Note:** When setting up a new machine these values will need to scale with the overall size of the device/domain. Additionally, one should perform a convergence study, by increasing resolution (decreasing target size) by at least a factor of two in all regions to ensure the results are not sensitive to your choice of grid size.

# %%
plasma_dx = 0.06
coil_dx = 0.05
vv_dx = 0.01
vac_dx = 0.14

# %% [markdown]
# ## Define regions and attributes
# We now create and define the various logical mesh regions. In the NSTX-U case we have 4 region groups:
#  - `air`: The region outside the limiter
#  - `plasma`: The region inside the limiter where the plasma will exist
#  - `plate-,...`: The vacuum vessel and other large, electrically conductive components
#  - `PF1AU,...`: The poloidal field coils
#
# For NSTX-U, several coils are each composed of many distributed windings, and are grouped into single coil sets using the `coil_set` and `nTurns` arguments to \ref OpenFUSIONToolkit.TokaMaker.gs_Domain.define_region "define_region()".
#
# **Note:** By default, X-points are only searched for in the plasma region. The argument `allow_xpoints` to \ref OpenFUSIONToolkit.TokaMaker.gs_Domain.define_region "define_region()" could be used in other regions to allow inactive x-points in a specific region.
#
# For each region you can provide a target size and one of four region types:
#  - `plasma`: The region where the plasma can exist and the classic Grad-Shafranov equation with $F*F'$ and $P'$ are allowed. **There can only be one region of this type**
#  - `vacuum`: A region where no current can flow and $\nabla^* \psi = 0$ is solved
#  - `boundary`: A special case of the `vacuum` region, which forms the outer boundary of the computational domain. **A region of this type is required if more than one region is specified**
#  - `conductor`: A region where toroidal current can flow passively (no externally applied voltage). For this type of region the resistivity should be specified with the argument `eta` in units of $\omega \mathrm{-m}$.
#  - `coil`: A region where toroidal current can flow with specified amplitude through \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.set_coil_currents "set_coil_currents()" or via shape optimization \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.set_coil_reg "set_coil_reg()" and \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.set_isoflux "set_isoflux()"

# %%
# Create a G-S domain
gs_mesh = gs_Domain(zpad=[1.2,1.2],rpad=1.1)
# Define region information for mesh
gs_mesh.define_region('air',vac_dx,'boundary')    # Define the bounding region
gs_mesh.define_region('plasma',plasma_dx,'plasma')    # Define the plasma region and resolution

# Define regions for VV
# Some details are excluded to simplify the model
for key in NSTXU_geom['vv']:
    if key.startswith('plate-'):
        gs_mesh.define_region(key,vv_dx,'conductor',eta=1.7e-8) # Passive stabilizing plates (copper)
    elif 'dVV' in key:
        gs_mesh.define_region(key,vv_dx,'conductor',eta=7.0e-7) # Other conductors (mostly stainless steel)

# Define each of the PF coils
for key, coil in NSTXU_geom['coils'].items():
    if key.startswith('CS'):
        gs_mesh.define_region(key,min(min(coil['w'],coil['h'])/2.0,coil_dx),'coil',nTurns=coil['nturns'], coil_set='CS')
    elif key.startswith('PF1'):
        gs_mesh.define_region(key,min(min(coil['w'],coil['h'])/2.0,coil_dx),'coil',nTurns=coil['nturns'])
    elif key.startswith('PF4'):
        gs_mesh.define_region(key,min(min(coil['w'],coil['h'])/2.0,coil_dx),'coil',nTurns=coil['nturns'], coil_set='PF4')
    elif key.startswith('PF5'):
        gs_mesh.define_region(key,min(min(coil['w'],coil['h'])/2.0,coil_dx),'coil',nTurns=coil['nturns'], coil_set='PF5')
    else:
        gs_mesh.define_region(key,min(min(coil['w'],coil['h'])/2.0,coil_dx),'coil',nTurns=coil['nturns'],\
        coil_set=key[:4])

# %% [markdown]
# ## Define geometry for region boundaries
# Once the region types and properties are defined we now define the geometry of the mesh using shapes and references to the defined regions.
#  1. We add the limiter contour as a "polygon", referencing `plasma` as the region enclosed by the contour and `air` as the region outside the contour.
#  2. We add each of the segments that compose the vacuum vessel.
#  3. We add each of the Central Solenoid and Poloidal Field coils. We also reference `air` as the region outside each coil.

# %%
# Define 
gs_mesh.add_polygon(NSTXU_geom['limiter'][:-1],'plasma',parent_name='air') 

# Define regions for VV
for key in NSTXU_geom['vv']:
    if key.startswith('plate-') or 'dVV' in key:
        gs_mesh.add_polygon(NSTXU_geom['vv'][key]['contour'],key,parent_name='air')

# Converts the EFIT geometry specification used in the NSTX-U geometry file to polygon vertices
def make_rectangle(rc,zc,w,h):
    contour = np.asarray([
        [-w/2.0, -h/2.0],
        [+w/2.0, -h/2.0],
        [+w/2.0, +h/2.0],
        [-w/2.0, +h/2.0]
    ])
    contour[:,0] += rc
    contour[:,1] += zc
    return contour

# Construct up-down symmetric Central Solenoid geometry from individual segments
for key, coil in NSTXU_geom['coils'].items():
    if key.startswith('CS') and key[3] == 'U':
        coil['contour'] = make_rectangle(coil['rc'],coil['zc'],coil['w'],coil['h'])

NSTXU_geom['coils']['CS1U']['contour']=np.insert(NSTXU_geom['coils']['CS1U']['contour'],2,NSTXU_geom['coils']['CS2U']['contour'][-1,:],axis=0)
NSTXU_geom['coils']['CS2U']['contour']=np.insert(NSTXU_geom['coils']['CS2U']['contour'],2,NSTXU_geom['coils']['CS3U']['contour'][-1,:],axis=0)
NSTXU_geom['coils']['CS3U']['contour']=np.insert(NSTXU_geom['coils']['CS3U']['contour'],2,NSTXU_geom['coils']['CS4U']['contour'][-1,:],axis=0)
NSTXU_geom['coils']['CS1L']['contour']=NSTXU_geom['coils']['CS1U']['contour'].copy(); NSTXU_geom['coils']['CS1L']['contour'][:,1] *= -1.0
NSTXU_geom['coils']['CS2L']['contour']=NSTXU_geom['coils']['CS2U']['contour'].copy(); NSTXU_geom['coils']['CS2L']['contour'][:,1] *= -1.0
NSTXU_geom['coils']['CS3L']['contour']=NSTXU_geom['coils']['CS3U']['contour'].copy(); NSTXU_geom['coils']['CS3L']['contour'][:,1] *= -1.0
NSTXU_geom['coils']['CS4L']['contour']=NSTXU_geom['coils']['CS4U']['contour'].copy(); NSTXU_geom['coils']['CS4L']['contour'][:,1] *= -1.0


# Define each of the PF coils
for key, coil in NSTXU_geom['coils'].items():
    if key.startswith('CS'):
        gs_mesh.add_polygon(coil['contour'],key,parent_name='air')
    else:
        gs_mesh.add_rectangle(coil['rc'],coil['zc'],coil['w'],coil['h'],key,parent_name='air')
# Out:
#   Warning: sliver (angle=54.7) detected at point 1 (1.3476889064863016, 1.0543500049999999)
#   Warning: sliver (angle=54.7) detected at point 3 (1.1185110835136982, 1.356549995)
#   Warning: sliver (angle=54.7) detected at point 2 (1.3476889064863016, -1.0543500049999999)

# %% [markdown]
# ## Plot topology
# After defining the logical and physical topology we can now plot the curves within the definitions to double check everything is in the right place.

# %%
fig, ax = plt.subplots(1,1,figsize=(4,6),constrained_layout=True)
gs_mesh.plot_topology(fig,ax)

# %% [markdown]
# ## Create mesh
# Now we generate the actual mesh using the \ref OpenFUSIONToolkit.TokaMaker.gs_Domain.build_mesh "build_mesh()" method. Additionally, if `coil` and/or `conductor` regions are defined the \ref OpenFUSIONToolkit.TokaMaker.gs_Domain.get_coils "get_coils()" and \ref OpenFUSIONToolkit.TokaMaker.gs_Domain.get_conductors "get_conductors()" methods should also be called to get descriptive dictionaries for later use in TokaMaker. This step may take a few moments as [triangle](https://www.cs.cmu.edu/~quake/triangle.html) generates the mesh.
#
# Note that, as is common with unstructured meshes, the mesh is stored as a list of points `mesh_pts` of size (np,2), a list of cells formed from three points each `mesh_lc` of size (nc,3), and an array providing a region id number for each cell `mesh_reg` of size (nc,), which is mapped to the names above using the `coil_dict` and `cond_dict` dictionaries.

# %%
mesh_pts, mesh_lc, mesh_reg = gs_mesh.build_mesh()
coil_dict = gs_mesh.get_coils()
cond_dict = gs_mesh.get_conductors()
# Out:
# Assembling regions:
#   Warning: small feature (dl=1.30E-03) detected at point 3 (0.441300005, 1.50944602)
#   Warning: small feature (dl=2.04E-02) detected at point 7 (0.597636998, 1.60279095)
#   Warning: small feature (dl=7.03E-03) detected at point 10 (0.847546995, 1.50672805)
#   Warning: small feature (dl=5.27E-03) detected at point 12 (0.960754991, 1.46964395)
#   Warning: small feature (dl=1.25E-02) detected at point 14 (1.04330003, 1.44251299)
#   Warning: small feature (dl=1.25E-02) detected at point 31 (1.04330003, -1.42999995)
#   Warning: small feature (dl=5.27E-03) detected at point 33 (0.96410799, -1.47370803)
#   Warning: small feature (dl=7.03E-03) detected at point 35 (0.849960029, -1.51333201)
#   Warning: small feature (dl=2.04E-02) detected at point 38 (0.597636998, -1.58241999)
#   Warning: small feature (dl=1.30E-03) detected at point 42 (0.440003991, -1.50944602)
#   Warning: small feature (dl=4.70E-03) detected at point 87 (0.42075000515, 1.917749970145)
#   Warning: small feature (dl=4.70E-03) detected at point 109 (0.42544998935, -1.917749970145)
#   # of unique points    = 5714
#   # of unique segments  = 237
# Generating mesh:
#   # of points  = 16122
#   # of cells   = 32138
#   # of regions = 40

# %% [markdown]
# ## Plot resulting regions and grid
# We now plot the mesh by region to inspect proper generation.

# %%
fig, ax = plt.subplots(2,2,figsize=(8,8),constrained_layout=True)
gs_mesh.plot_mesh(fig,ax)

# %% [markdown]
# ## Save mesh for later use
# As generation of the mesh often takes comparable, or longer, time compare to runs in TokaMaker it is useful to separate generation of the mesh into a different script as demonstrated here. The method \ref OpenFUSIONToolkit.TokaMaker.save_gs_mesh "save_gs_mesh()" can be used to save the resulting information for later use. This is done using and an [HDF5](https://www.hdfgroup.org/solutions/hdf5/) file through the [h5py](https://www.h5py.org/) library.

# %%
save_gs_mesh(mesh_pts,mesh_lc,mesh_reg,coil_dict,cond_dict,'NSTXU_mesh.h5')
