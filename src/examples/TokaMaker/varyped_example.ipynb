# %% [markdown]
# # VARYPED Equilibrium Scan Example
#
# Demonstrates the `varyped` module for creating equilibrium scans of self-consistently scaled pressure and current density profiles using input
# g-files and p-files.
#
# **What this notebook covers:**
# 1. Loading TokaMaker and input files
# 2. Running scan with single scale value
# 3. Running a full equilibrium scan with various scaling values
# 4. Comparing original vs scaled profiles

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(10,6)
plt.rcParams['font.weight']='bold'
plt.rcParams['axes.labelweight']='bold'
plt.rcParams['lines.linewidth']=2
plt.rcParams['lines.markeredgewidth']=2
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
tokamaker_python_path = 'PATH_TO_OFT'
tokamaker_python_path = os.getenv("OFT_ROOTPATH")
#PATH_TO_OFT should be replaced with where your OFT is installed

if tokamaker_python_path is not None:
    sys.path.append(os.path.join(tokamaker_python_path,'python'))

from OpenFUSIONToolkit import OFT_env
from OpenFUSIONToolkit.TokaMaker import TokaMaker, meshing, eqdsk
import varyped

# %% [markdown]
# ## 1. Loading TokaMaker and input files

# %%
#Loading gfile using eqdsk.py
gfile = 'TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk'
g_eq = eqdsk.read_geqdsk(gfile)

#Loading TokaMaker object
myOFT = OFT_env(nthreads=2)
mygs = TokaMaker(myOFT)
mygs.settings.maxits = 200

mesh_pts,mesh_lc,mesh_reg,coil_dict,cond_dict = meshing.load_gs_mesh('DIIID_mesh.h5') ##D3D mesh loaded in
mygs.setup_mesh(mesh_pts, mesh_lc, mesh_reg)
mygs.setup_regions(cond_dict=cond_dict,coil_dict=coil_dict)
mygs.setup(order=2,F0=abs(g_eq.R_center*g_eq.B_center))
mygs.set_coil_vsc({'F9A': 1.0, 'F9B': -1.0})

isoflux_pts = np.column_stack((g_eq.boundary_R, g_eq.boundary_Z))
weights = np.ones(len(isoflux_pts))*100.
mygs.set_isoflux_constraints(isoflux_pts, weights) ##isoflux and isoflux weights set

#Loading pfile using eqdsk.py
pfile = 'TkMkr_D3Dlike_Hmode_BSamp=1.0.peqdsk'
p_eq = eqdsk.read_pfile(pfile)
# Out:
# #----------------------------------------------
# Open FUSION Toolkit Initialized
# Development branch:    main
# Revision id:           51794ed
# Parallelization Info:
#   Not compiled with MPI
#   # of OpenMP threads =    2
# Integer Precisions    =    4   8
# Float Precisions      =    4   8  10
# Complex Precisions    =    4   8
# LA backend            = native
# #----------------------------------------------
#
#
# **** Loading OFT surface mesh
#
# **** Generating surface grid level  1
#   Generating boundary domain linkage
#   Mesh statistics:
#     Area         =  1.574E+01
#     # of points  =    8910
#     # of edges   =   26567
#     # of cells   =   17658
#     # of boundary points =     160
#     # of boundary edges  =     160
#     # of boundary cells  =     160
#   Resolution statistics:
#     hmin =  8.702E-04
#     hrms =  4.833E-02
#     hmax =  1.540E-01
#   Surface grounded at vertex    1733
#
#
# **** Creating Lagrange FE space
#   Order  =    2
#   Minlev =   -1
#
#  Computing flux BC matrix
#  Inverting real matrix
#    Time =    2.7784369999999999E-003

# %%
target_currents = {
    'ECOILA': -0.977888676757812/61.0,
    'ECOILB': -0.962711173828125/61.0,
    'F1A': 0.115971984375,
    'F2A': 0.05980789453125,
    'F3A': -0.03076001171875,
    'F4A': -0.0401077421875,
    'F5A': 0.000723009033203125,
    'F6A': -0.1178582568125,
    'F7A': 0.0341264296875,
    'F8A': -0.05660116015625,
    'F9A': 0.236625375,
    'F1B': 0.128368578125,
    'F2B': 0.0763701328125,
    'F3B': -0.02234583203125,
    'F4B': -0.13314096875,
    'F5B': 0.000399709045410156,
    'F6B': -0.15356990625,
    'F7B': 0.0415082109375,
    'F8B': -0.05138975390625,
    'F9B': 0.252380265625
}
for key in target_currents:
    target_currents[key] *= 1.E6

# Set regularization weights
regularization_terms = []
for name, target_current in target_currents.items():
    # Set specific target currents from input equilibrium and different weights depending on the coil set
    if name.startswith('ECOIL'):
        regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=target_current,weight=1.0))
    elif name.startswith('F'):
        if name.startswith('F5'):
            regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=target_current,weight=1.))
        else:
            regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=target_current,weight=1.))
# Set zero target current and small weight on virtual VSC to allow up-down adjustment
regularization_terms.append(mygs.coil_reg_term({'#VSC': 1.0},target=0.0,weight=1.E-2))

# Pass regularization terms to TokaMaker
mygs.set_coil_reg(reg_terms=regularization_terms)

# %% [markdown]
# ## Function Syntax
#
# An equilibrium scan is performed by calling `varyped.equilibrium_scan` with the following parameters:
# - `t_object`: TokaMaker Grad-Shafranov Solver Object
# - `pfile`: p-file object containing input kinetic profiles
# - `gfile`: g-file object containing standard GEQDSK equilibrium data
# - `scaling_values`: array-like object of non-decreasing positive scalar values
# - `path_to_output`: (str) path to directory where outputs will be created, defaults to the current working directory
# - `filenames`: (str) name for output files (typically of the form #####.####, where # are integers), defaults to 10000.0000
# - `file_output`: Boolean value that will determine if equilibrium scan generates output files
#
# The `equilibrium_scan` function also returns a list of dictionaries so that certain run results can be easily retreived. The returned value can also be passed into `varyped.plot_varyped_results` to plot the resulting pressure, current density, and pressure derivative profiles. Each dictionary contains the following information:
# - `scale_p`: Pressure Pedestal scaling factor
# - `scale_j`: Current Density Edge Spike scaling factor
# - `gfile_name`: Name of the output g-file for the given pressure-current scaling value pair
# - `pfile_name`: Name of the output p-file for the given pressure-current scaling value pair
# - `Ip_target`: Target total plasma current
# - `Ip_final`: Achieved total plasma current
# - `pax_target`: Target pressure on axis
# - `W_target`: Target total work stored in plasma
# - `W_final`: Achieved total work stored in plasma
# - `eq_snapshot`: TokaMaker_equilibrium object, snapshot of equilibria for given pressure-current scaling value pair

# %% [markdown]
# ## 2. Running a scan with a single scaling value

# %%
no_scaling = 1 #Inputting a single float scaling value is handled as well
no_scaling_results = varyped.equilibrium_scan(mygs, 
                                              p_eq, 
                                              g_eq, 
                                              no_scaling, 
                                              path_to_output=None, 
                                              filenames=None)
# Out:
# Scaling Values Array: [1]
# [equilibrium_scan] Using pfile psi_n: 514 points (pfile has higher resolution than gfile: 257)
#     26  1.0000E+00 -4.9073E-06  1.3599E-06  1.7065E+00 -1.1716E-02  1.2037E+05
#     27  1.0000E+00 -4.9073E-06  5.5049E-07  1.7065E+00 -1.1716E-02  1.2037E+05
#  Timing:   2.7437631889988552
#    Source:    0.76522676699823933
#    Solve:     0.17852350600151112
#    Boundary:   9.3239159978111275E-003
#    Other:      1.7906890000012936
# Saving gEQDSK: /home/kevcl/PlasmaLab/varyped_like_package/varyped_like_tools/g_scaled_up_example_1.5_1.5.geqdsk
# Saving pFile: /home/kevcl/PlasmaLab/varyped_like_package/varyped_like_tools/p_scaled_up_example_1.5_1.5
#
#  Varyped Equilibrium Run (1.5,1.5) Quick Results:
# {'Ip_final': 1199445.2795400948,
#  'Ip_target': 1200039.5,
#  'W_final': 58032.003346786725,
#  'W_target': 58032.00334677151,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154381ac0>,
#  'gfile_name': 'g_scaled_up_example_1.5_1.5.geqdsk',
#  'pax_target': '36.56012182334194 kPa',
#  'pfile_name': 'p_scaled_up_example_1.5_1.5',
#  'scale_j': 1.5,
#  'scale_p': 1.5}

# %% [markdown]
# ## 3. Running a full equilibrium scan

# %%
#a scaling values array of length n will produce 2*(n^2) output files,
#so file_output is toggled to False for this example!
scaling_values = np.linspace(0.5, 1.5, 11)

#an example for how files can be named
filenames_ex_full_run = '_full_run_example'

scaling_results = varyped.equilibrium_scan(mygs, 
                                           p_eq, 
                                           g_eq, 
                                           scaling_values, 
                                           path_to_output=None, 
                                           filenames=filenames_ex_full_run,
                                           file_output=False)
# Out:
# Scaling Values Array: [0.5 0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5]
# [equilibrium_scan] Using pfile psi_n: 514 points (pfile has higher resolution than gfile: 257)
# Starting non-linear GS solver
#      1  1.0000E+00 -4.2498E-06  1.1012E-02  1.7243E+00 -4.5490E-02  1.9042E+05
#      2  1.0000E+00 -4.0854E-06  5.4103E-03  1.7160E+00 -3.4769E-02  1.4982E+05
#      3  1.0000E+00 -4.1629E-06  4.2064E-03  1.7121E+00 -2.6980E-02  1.3066E+05
#      4  1.0000E+00 -4.2439E-06  2.4511E-03  1.7101E+00 -2.1608E-02  1.2432E+05
#      5  1.0000E+00 -4.2979E-06  1.2718E-03  1.7092E+00 -1.8017E-02  1.2137E+05
#      6  1.0000E+00 -4.3295E-06  7.8633E-04  1.7088E+00 -1.5659E-02  1.1954E+05
#      7  1.0000E+00 -4.3472E-06  4.7632E-04  1.7086E+00 -1.4039E-02  1.1849E+05
#      8  1.0000E+00 -4.3568E-06  2.9307E-04  1.7085E+00 -1.3046E-02  1.1776E+05
#      9  1.0000E+00 -4.3621E-06  1.7114E-04  1.7085E+00 -1.2403E-02  1.1735E+05
#     10  1.0000E+00 -4.3649E-06  1.0399E-04  1.7084E+00 -1.1988E-02  1.1710E+05
#     11  1.0000E+00 -4.3663E-06  6.4705E-05  1.7084E+00 -1.1719E-02  1.1694E+05
#      5  1.0000E+00 -4.7305E-06  2.7158E-04  1.7073E+00 -1.1535E-02  1.2129E+05
#      6  1.0000E+00 -4.7430E-06  1.4126E-04  1.7073E+00 -1.1539E-02  1.2108E+05
#      7  1.0000E+00 -4.7498E-06  6.6504E-05  1.7073E+00 -1.1543E-02  1.2093E+05
#      8  1.0000E+00 -4.7537E-06  5.9688E-05  1.7073E+00 -1.1545E-02  1.2079E+05
#      9  1.0000E+00 -4.7559E-06  2.9156E-05  1.7073E+00 -1.1547E-02  1.2071E+05
#     10  1.0000E+00 -4.7572E-06  1.8432E-05  1.7073E+00 -1.1549E-02  1.2065E+05
#     11  1.0000E+00 -4.7579E-06  1.6830E-05  1.7073E+00 -1.1550E-02  1.2062E+05
#     12  1.0000E+00 -4.7584E-06  8.0871E-06  1.7073E+00 -1.1550E-02  1.2061E+05
#     13  1.0000E+00 -4.7587E-06  4.7842E-06  1.7073E+00 -1.1551E-02  1.2060E+05
#     14  1.0000E+00 -4.7589E-06  3.0724E-06  1.7073E+00 -1.1551E-02  1.2059E+05
#     15  1.0000E+00 -4.7591E-06  2.0162E-06  1.7073E+00 -1.1551E-02  1.2059E+05
#     16  1.0000E+00 -4.7591E-06  1.3312E-06  1.7073E+00 -1.1552E-02  1.2058E+05
#     17  1.0000E+00 -4.7592E-06  8.7982E-07  1.7073E+00 -1.1552E-02  1.2058E+05
#  Timing:   1.7738997630003723
#    Source:    0.48199187100544805
#    Solve:     0.11200987397751305
#    Boundary:   5.8579690012265928E-003
#    Other:      1.1740400490161846
# Starting non-linear GS solver
#      1  1.0000E+00 -4.2919E-06  6.3686E-03  1.7080E+00 -1.1492E-02  1.1528E+05
# ...
#  'W_final': 67298.58964523827,
#  'W_target': 67298.58964523814,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154380e60>,
#  'gfile_name': 'g_full_run_example_1.2000000000000002_1.5.geqdsk',
#  'pax_target': '45.42928829940622 kPa',
#  'pfile_name': 'p_full_run_example_1.2000000000000002_1.5',
#  'scale_j': np.float64(1.5),
#  'scale_p': np.float64(1.2000000000000002)}
#
#  Varyped Equilibrium Run (1.3,0.5) Quick Results:
# {'Ip_final': 1360271.260694282,
#  'Ip_target': 1200039.5,
#  'W_final': 67831.78532485299,
#  'W_target': 67831.78532484856,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154419190>,
#  'gfile_name': 'g_full_run_example_1.3_0.5.geqdsk',
#  'pax_target': '40.525676956257875 kPa',
#  'pfile_name': 'p_full_run_example_1.3_0.5',
#  'scale_j': np.float64(0.5),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,0.6) Quick Results:
# {'Ip_final': 1275703.0337526489,
#  'Ip_target': 1200039.5,
#  'W_final': 63370.20103525088,
#  'W_target': 63370.20103525068,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154437860>,
#  'gfile_name': 'g_full_run_example_1.3_0.6.geqdsk',
#  'pax_target': '39.68602278364371 kPa',
#  'pfile_name': 'p_full_run_example_1.3_0.6',
#  'scale_j': np.float64(0.6),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,0.7) Quick Results:
# {'Ip_final': 1288353.8528762634,
#  'Ip_target': 1200039.5,
#  'W_final': 63893.33241045386,
#  'W_target': 63893.332410454495,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1cf647e30>,
#  'gfile_name': 'g_full_run_example_1.3_0.7.geqdsk',
#  'pax_target': '39.861376457387166 kPa',
#  'pfile_name': 'p_full_run_example_1.3_0.7',
#  'scale_j': np.float64(0.7),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,0.8) Quick Results:
# {'Ip_final': 1297548.64640614,
#  'Ip_target': 1200039.5,
#  'W_final': 64252.635706624584,
#  'W_target': 64252.63570662481,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154383ce0>,
#  'gfile_name': 'g_full_run_example_1.3_0.8.geqdsk',
#  'pax_target': '39.942058347843385 kPa',
#  'pfile_name': 'p_full_run_example_1.3_0.8',
#  'scale_j': np.float64(0.8),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,0.9) Quick Results:
# {'Ip_final': 1307175.9089646395,
#  'Ip_target': 1200039.5,
#  'W_final': 64634.8489229552,
#  'W_target': 64634.8489229524,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb15441bfe0>,
#  'gfile_name': 'g_full_run_example_1.3_0.9.geqdsk',
#  'pax_target': '40.021868551452926 kPa',
#  'pfile_name': 'p_full_run_example_1.3_0.9',
#  'scale_j': np.float64(0.9),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,1.0) Quick Results:
# {'Ip_final': 1316799.112107537,
#  'Ip_target': 1200039.5,
#  'W_final': 65019.31431068735,
#  'W_target': 65019.3143106846,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1543e0b60>,
#  'gfile_name': 'g_full_run_example_1.3_1.0.geqdsk',
#  'pax_target': '40.1001425131356 kPa',
#  'pfile_name': 'p_full_run_example_1.3_1.0',
#  'scale_j': np.float64(1.0),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,1.1) Quick Results:
# {'Ip_final': 1327136.0692816586,
#  'Ip_target': 1200039.5,
#  'W_final': 65438.30249830624,
#  'W_target': 65438.30249830302,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154435d90>,
#  'gfile_name': 'g_full_run_example_1.3_1.1.geqdsk',
#  'pax_target': '40.17717119977218 kPa',
#  'pfile_name': 'p_full_run_example_1.3_1.1',
#  'scale_j': np.float64(1.1),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,1.2000000000000002) Quick Results:
# {'Ip_final': 1337905.1625375785,
#  'Ip_target': 1200039.5,
#  'W_final': 65878.21911265241,
#  'W_target': 65878.21911264847,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb15442f980>,
#  'gfile_name': 'g_full_run_example_1.3_1.2000000000000002.geqdsk',
#  'pax_target': '40.25094239509096 kPa',
#  'pfile_name': 'p_full_run_example_1.3_1.2000000000000002',
#  'scale_j': np.float64(1.2000000000000002),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,1.3) Quick Results:
# {'Ip_final': 1348802.007628613,
#  'Ip_target': 1200039.5,
#  'W_final': 66325.26526457687,
#  'W_target': 66325.26526457278,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb15441a360>,
#  'gfile_name': 'g_full_run_example_1.3_1.3.geqdsk',
#  'pax_target': '40.32249475961125 kPa',
#  'pfile_name': 'p_full_run_example_1.3_1.3',
#  'scale_j': np.float64(1.3),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,1.4) Quick Results:
# {'Ip_final': 1360134.9712614617,
#  'Ip_target': 1200039.5,
#  'W_final': 66795.65136301855,
#  'W_target': 66795.6513630139,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154418920>,
#  'gfile_name': 'g_full_run_example_1.3_1.4.geqdsk',
#  'pax_target': '40.392519743372866 kPa',
#  'pfile_name': 'p_full_run_example_1.3_1.4',
#  'scale_j': np.float64(1.4),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.3,1.5) Quick Results:
# {'Ip_final': 1372081.720018985,
#  'Ip_target': 1200039.5,
#  'W_final': 67298.32679232486,
#  'W_target': 67298.32679232067,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154381490>,
#  'gfile_name': 'g_full_run_example_1.3_1.5.geqdsk',
#  'pax_target': '40.46042849611592 kPa',
#  'pfile_name': 'p_full_run_example_1.3_1.5',
#  'scale_j': np.float64(1.5),
#  'scale_p': np.float64(1.3)}
#
#  Varyped Equilibrium Run (1.4,0.5) Quick Results:
# {'Ip_final': 1360268.7125188557,
#  'Ip_target': 1200039.5,
#  'W_final': 67831.62228275213,
#  'W_target': 67831.6222827513,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154382900>,
#  'gfile_name': 'g_full_run_example_1.4_0.5.geqdsk',
#  'pax_target': '36.345376724899275 kPa',
#  'pfile_name': 'p_full_run_example_1.4_0.5',
#  'scale_j': np.float64(0.5),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,0.6) Quick Results:
# {'Ip_final': 1275702.230296612,
#  'Ip_target': 1200039.5,
#  'W_final': 63370.14596638926,
#  'W_target': 63370.145966386524,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1543811f0>,
#  'gfile_name': 'g_full_run_example_1.4_0.6.geqdsk',
#  'pax_target': '35.37267966361328 kPa',
#  'pfile_name': 'p_full_run_example_1.4_0.6',
#  'scale_j': np.float64(0.6),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,0.7) Quick Results:
# {'Ip_final': 1288352.5889115122,
#  'Ip_target': 1200039.5,
#  'W_final': 63893.25559867907,
#  'W_target': 63893.255598675416,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154437a40>,
#  'gfile_name': 'g_full_run_example_1.4_0.7.geqdsk',
#  'pax_target': '35.575611690556855 kPa',
#  'pfile_name': 'p_full_run_example_1.4_0.7',
#  'scale_j': np.float64(0.7),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,0.8) Quick Results:
# {'Ip_final': 1297547.0490520976,
#  'Ip_target': 1200039.5,
#  'W_final': 64252.54170982971,
#  'W_target': 64252.541709827245,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154436b40>,
#  'gfile_name': 'g_full_run_example_1.4_0.8.geqdsk',
#  'pax_target': '35.66897880027327 kPa',
#  'pfile_name': 'p_full_run_example_1.4_0.8',
#  'scale_j': np.float64(0.8),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,0.9) Quick Results:
# {'Ip_final': 1307173.9652777144,
#  'Ip_target': 1200039.5,
#  'W_final': 64634.73687186966,
#  'W_target': 64634.73687186829,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154418ce0>,
#  'gfile_name': 'g_full_run_example_1.4_0.9.geqdsk',
#  'pax_target': '35.761372748543664 kPa',
#  'pfile_name': 'p_full_run_example_1.4_0.9',
#  'scale_j': np.float64(0.9),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,1.0) Quick Results:
# {'Ip_final': 1316796.712399469,
#  'Ip_target': 1200039.5,
#  'W_final': 65019.17814701656,
#  'W_target': 65019.17814701579,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1543e1910>,
#  'gfile_name': 'g_full_run_example_1.4_1.0.geqdsk',
#  'pax_target': '35.852037426584594 kPa',
#  'pfile_name': 'p_full_run_example_1.4_1.0',
#  'scale_j': np.float64(1.0),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,1.1) Quick Results:
# {'Ip_final': 1327133.1457803003,
#  'Ip_target': 1200039.5,
#  'W_final': 65438.141824554514,
#  'W_target': 65438.14182455297,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154435520>,
#  'gfile_name': 'g_full_run_example_1.4_1.1.geqdsk',
#  'pax_target': '35.94128056678341 kPa',
#  'pfile_name': 'p_full_run_example_1.4_1.1',
#  'scale_j': np.float64(1.1),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,1.2000000000000002) Quick Results:
# {'Ip_final': 1337901.671107456,
#  'Ip_target': 1200039.5,
#  'W_final': 65878.03155310507,
#  'W_target': 65878.03155310356,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154f098e0>,
#  'gfile_name': 'g_full_run_example_1.4_1.2000000000000002.geqdsk',
#  'pax_target': '36.026773173502114 kPa',
#  'pfile_name': 'p_full_run_example_1.4_1.2000000000000002',
#  'scale_j': np.float64(1.2000000000000002),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,1.3) Quick Results:
# {'Ip_final': 1348803.0441828629,
#  'Ip_target': 1200039.5,
#  'W_final': 66325.30327912416,
#  'W_target': 66325.30327912307,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154437380>,
#  'gfile_name': 'g_full_run_example_1.4_1.3.geqdsk',
#  'pax_target': '36.10970772631628 kPa',
#  'pfile_name': 'p_full_run_example_1.4_1.3',
#  'scale_j': np.float64(1.3),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,1.4) Quick Results:
# {'Ip_final': 1360129.7136896471,
#  'Ip_target': 1200039.5,
#  'W_final': 66795.37190459248,
#  'W_target': 66795.37190459194,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154437710>,
#  'gfile_name': 'g_full_run_example_1.4_1.4.geqdsk',
#  'pax_target': '36.19091863249684 kPa',
#  'pfile_name': 'p_full_run_example_1.4_1.4',
#  'scale_j': np.float64(1.4),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.4,1.5) Quick Results:
# {'Ip_final': 1372075.2233305047,
#  'Ip_target': 1200039.5,
#  'W_final': 67297.99393635418,
#  'W_target': 67297.99393635358,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1543e3830>,
#  'gfile_name': 'g_full_run_example_1.4_1.5.geqdsk',
#  'pax_target': '36.26967764606117 kPa',
#  'pfile_name': 'p_full_run_example_1.4_1.5',
#  'scale_j': np.float64(1.5),
#  'scale_p': np.float64(1.4)}
#
#  Varyped Equilibrium Run (1.5,0.5) Quick Results:
# {'Ip_final': 1360262.2378588347,
#  'Ip_target': 1200039.5,
#  'W_final': 67831.27708375982,
#  'W_target': 67831.27708374565,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1548f7fe0>,
#  'gfile_name': 'g_full_run_example_1.5_0.5.geqdsk',
#  'pax_target': '32.734475024800204 kPa',
#  'pfile_name': 'p_full_run_example_1.5_0.5',
#  'scale_j': np.float64(0.5),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,0.6) Quick Results:
# {'Ip_final': 1275701.7032694938,
#  'Ip_target': 1200039.5,
#  'W_final': 63370.10429471747,
#  'W_target': 63370.1042947155,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154435100>,
#  'gfile_name': 'g_full_run_example_1.5_0.6.geqdsk',
#  'pax_target': '31.66277025481221 kPa',
#  'pfile_name': 'p_full_run_example_1.5_0.6',
#  'scale_j': np.float64(0.6),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,0.7) Quick Results:
# {'Ip_final': 1288351.1582014542,
#  'Ip_target': 1200039.5,
#  'W_final': 63893.17030995595,
#  'W_target': 63893.17030995532,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb15441b080>,
#  'gfile_name': 'g_full_run_example_1.5_0.7.geqdsk',
#  'pax_target': '31.88612687371822 kPa',
#  'pfile_name': 'p_full_run_example_1.5_0.7',
#  'scale_j': np.float64(0.7),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,0.8) Quick Results:
# {'Ip_final': 1297545.334805426,
#  'Ip_target': 1200039.5,
#  'W_final': 64252.44171902533,
#  'W_target': 64252.441719024115,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154381e20>,
#  'gfile_name': 'g_full_run_example_1.5_0.8.geqdsk',
#  'pax_target': '31.988897584261412 kPa',
#  'pfile_name': 'p_full_run_example_1.5_0.8',
#  'scale_j': np.float64(0.8),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,0.9) Quick Results:
# {'Ip_final': 1307171.4433512546,
#  'Ip_target': 1200039.5,
#  'W_final': 64634.59802162463,
#  'W_target': 64634.598021623075,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb154434e60>,
#  'gfile_name': 'g_full_run_example_1.5_0.9.geqdsk',
#  'pax_target': '32.09062817828654 kPa',
#  'pfile_name': 'p_full_run_example_1.5_0.9',
#  'scale_j': np.float64(0.9),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,1.0) Quick Results:
# {'Ip_final': 1316794.196492339,
#  'Ip_target': 1200039.5,
#  'W_final': 65019.03681332757,
#  'W_target': 65019.036813326944,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb18d60b530>,
#  'gfile_name': 'g_full_run_example_1.5_1.0.geqdsk',
#  'pax_target': '32.19051608382565 kPa',
#  'pfile_name': 'p_full_run_example_1.5_1.0',
#  'scale_j': np.float64(1.0),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,1.1) Quick Results:
# {'Ip_final': 1327130.382749858,
#  'Ip_target': 1200039.5,
#  'W_final': 65437.988036188486,
#  'W_target': 65437.98803618803,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1544199a0>,
#  'gfile_name': 'g_full_run_example_1.5_1.1.geqdsk',
#  'pax_target': '32.28885799165836 kPa',
#  'pfile_name': 'p_full_run_example_1.5_1.1',
#  'scale_j': np.float64(1.1),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,1.2000000000000002) Quick Results:
# {'Ip_final': 1337897.943082339,
#  'Ip_target': 1200039.5,
#  'W_final': 65877.83292810373,
#  'W_target': 65877.83292810361,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb18d6828d0>,
#  'gfile_name': 'g_full_run_example_1.5_1.2000000000000002.geqdsk',
#  'pax_target': '32.383086797347346 kPa',
#  'pfile_name': 'p_full_run_example_1.5_1.2000000000000002',
#  'scale_j': np.float64(1.2000000000000002),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,1.3) Quick Results:
# {'Ip_final': 1348798.8003889865,
#  'Ip_target': 1200039.5,
#  'W_final': 66325.07667888066,
#  'W_target': 66325.07667888045,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1543a4260>,
#  'gfile_name': 'g_full_run_example_1.5_1.3.geqdsk',
#  'pax_target': '32.47453280573537 kPa',
#  'pfile_name': 'p_full_run_example_1.5_1.3',
#  'scale_j': np.float64(1.3),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,1.4) Quick Results:
# {'Ip_final': 1360126.5082917174,
#  'Ip_target': 1200039.5,
#  'W_final': 66795.18785771966,
#  'W_target': 66795.18785771968,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1543a7f50>,
#  'gfile_name': 'g_full_run_example_1.5_1.4.geqdsk',
#  'pax_target': '32.56411665644838 kPa',
#  'pfile_name': 'p_full_run_example_1.5_1.4',
#  'scale_j': np.float64(1.4),
#  'scale_p': np.float64(1.5)}
#
#  Varyped Equilibrium Run (1.5,1.5) Quick Results:
# {'Ip_final': 1372070.85741899,
#  'Ip_target': 1200039.5,
#  'W_final': 67297.75393862532,
#  'W_target': 67297.75393862503,
#  'eq_snapshot': <OpenFUSIONToolkit.TokaMaker._core.TokaMaker_equilibrium object at 0x7fb1544a9160>,
#  'gfile_name': 'g_full_run_example_1.5_1.5.geqdsk',
#  'pax_target': '32.65098759769721 kPa',
#  'pfile_name': 'p_full_run_example_1.5_1.5',
#  'scale_j': np.float64(1.5),
#  'scale_p': np.float64(1.5)}

# %% [markdown]
# ## 4. Comparing and Plotting Results

# %% [markdown]
# This module contains a plotting function titled `varyped.plot_varyped_results` that accepts the *results* array returned by an equilibrium scan and plots the pressure, pressure derivative, and current profiles that are produced. The only parameters of the function is:
#
# - `results`: Varyped quick results array from running an equilibrium scan. The first entry in the array contains the scaling values used for the run, the input gfile object, and the input pfile object.

# %%
#Pressure plots for no scaling
varyped.plot_pressure_results(no_scaling_results)

# %%
#Current density plot for scaling up 
varyped.plot_current_results(scaling_up_results)

# %%
#Plot for full equilibrium run results
varyped.plot_varyped_results(scaling_results)
